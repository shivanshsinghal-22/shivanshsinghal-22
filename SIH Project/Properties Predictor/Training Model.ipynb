# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import optuna
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/kaggle/input/dataset-real-nalco/Real_final_Data_With_anomaly.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4548 entries, 0 to 4547
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   EMUL_OIL_L_TEMP_PV_VAL0        4548 non-null   float64
#  1   STAND_OIL_L_TEMP_PV_REAL_VAL0  4548 non-null   float64
#  2   GEAR_OIL_L_TEMP_PV_REAL_VAL0   4548 non-null   float64
#  3   EMUL_OIL_L_PR_VAL0             4548 non-null   float64
#  4   QUENCH_CW_FLOW_EXIT_VAL0       4548 non-null   float64
#  5   CAST_WHEEL_RPM_VAL0            4548 non-null   float64
#  6   BAR_TEMP_VAL0                  4548 non-null   float64
#  7   QUENCH_CW_FLOW_ENTRY_VAL0      4548 non-null   float64
#  8   GEAR_OIL_L_PR_VAL0             4548 non-null   float64
#  9   STANDS_OIL_L_PR_VAL0           4548 non-null   float64
#  10  TUNDISH_TEMP_VAL0              4548 non-null   float64
#  11  RM_MOTOR_COOL_WATER__VAL0      4548 non-null   float64
#  12  ROLL_MILL_AMPS_VAL0            4548 non-null   float64
#  13  RM_COOL_WATER_FLOW_VAL0        4548 non-null   float64
#  14  EMULSION_LEVEL_ANALO_VAL0      4548 non-null   float64
#  15     UTS                         4548 non-null   float64
#  16  Elongation                     4548 non-null   float64
#  17  Conductivity                   4548 non-null   float64
#  18  %SI                            4548 non-null   float64
#  19  %FE                            4548 non-null   float64
#  20  %TI                            4548 non-null   float64
#  21  %V                             4548 non-null   float64
#  22  %AL                            4548 non-null   float64
#  23  Furnace_Temperature            4548 non-null   float64
# dtypes: float64(24)
# memory usage: 852.9 KB

# %%
y_min = {}
y_max = {}

for cols in df.columns:
    min_v = df[cols].min()
    max_v = df[cols].max()
    y_min[cols] = min_v
    y_max[cols] = max_v

# %%
# Normalization function
def normalize_column(column):
    min_val = column.min()
    max_val = column.max()
    return (column - min_val) / (max_val - min_val)

# Inverse normalization function
def inverse_normalize_column(norm_column, min_val, max_val):
    return norm_column * (max_val - min_val) + min_val

# Normalize the data
normalized_data = df.apply(normalize_column)

# %%
target_cols = ['   UTS','Conductivity','Elongation']
input_cols = [col for col in df.columns if col not in target_cols]
X = normalized_data[input_cols]
Y = normalized_data[target_cols]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
import optuna
import xgboost as xgb
import pickle
from sklearn.metrics import mean_squared_error

# Step 3: Define the objective function for Optuna
def objective(trial, output_col, x_train, y_train, x_test, y_test):
    # Hyperparameter search space
    params = {
        
        "objective": "reg:squarederror",
        "tree_method": "auto",
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 15),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.5, log=True),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "subsample": trial.suggest_float("subsample", 0.5, 1),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1),
        "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-5, 10, log=True),
        
    }

    # Train the XGBoost regressor for the specific output
    model = xgb.XGBRegressor(**params)
    model.fit(x_train, y_train)

    # Evaluate on the test set
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)

    # Save the model if this is the best trial so far
    if mse < objective.best_mse[output_col]:
        objective.best_mse[output_col] = mse
        with open(f"xgboost_model_output_{output_col}.pkl", "wb") as f:
            pickle.dump(model, f)
    
    return mse

# Initialize best MSE tracker
objective.best_mse = {
    '   UTS': float("inf"),
    'Elongation': float("inf"),
    'Conductivity': float("inf"),
}

# Step 4: Run Optuna for each output parameter
outputs = ['   UTS', 'Elongation', 'Conductivity']  # Replace with your actual column names
for output_col in outputs:
    print(f"Optimizing for output parameter {output_col}...")
    study = optuna.create_study(direction="minimize")
    study.optimize(
        lambda trial: objective(trial, output_col, X_train, Y_train[output_col], X_test, Y_test[output_col]),
        n_trials=1000
    )
    print(f"Best MSE for output {output_col}: {objective.best_mse[output_col]}")
    print(f"The best model for output {output_col} is saved as 'xgboost_model_output_{output_col}.pkl'")
# Out:
# [I 2024-12-12 10:11:04,715] A new study created in memory with name: no-name-10de899c-50f5-43f9-9f7b-3f042b9b58f2
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:04,899] Trial 0 finished with value: 0.004123354113476689 and parameters: {'n_estimators': 192, 'max_depth': 3, 'min_child_weight': 6, 'learning_rate': 0.06138099912345952, 'gamma': 4.872193693923552, 'subsample': 0.6361285225924367, 'colsample_bytree': 0.7040276127257485, 'reg_alpha': 0.12666154523579443, 'reg_lambda': 0.0005835052330150139}. Best is trial 0 with value: 0.004123354113476689.
# Optimizing for output parameter    UTS...
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:04,982] Trial 1 finished with value: 0.004123851768133388 and parameters: {'n_estimators': 228, 'max_depth': 15, 'min_child_weight': 12, 'learning_rate': 0.03137932199859095, 'gamma': 3.6206908672603433, 'subsample': 0.959437270612547, 'colsample_bytree': 0.7711435014025512, 'reg_alpha': 0.046512441238235606, 'reg_lambda': 0.0003361919491244235}. Best is trial 0 with value: 0.004123354113476689.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:05,111] Trial 2 finished with value: 0.004123479714809492 and parameters: {'n_estimators': 396, 'max_depth': 7, 'min_child_weight': 3, 'learning_rate': 0.2239431715260686, 'gamma': 4.552223227824841, 'subsample': 0.8843052384442665, 'colsample_bytree': 0.7250299979505175, 'reg_alpha': 0.20077288102898236, 'reg_lambda': 0.0028505322431308473}. Best is trial 0 with value: 0.004123354113476689.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:05,297] Trial 3 finished with value: 0.004123498583573405 and parameters: {'n_estimators': 618, 'max_depth': 11, 'min_child_weight': 2, 'learning_rate': 0.23918635181831896, 'gamma': 4.1104372567972804, 'subsample': 0.6453823921639043, 'colsample_bytree': 0.5126478391178025, 'reg_alpha': 1.6404193839393952, 'reg_lambda': 0.8053804094486604}. Best is trial 0 with value: 0.004123354113476689.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:05,516] Trial 4 finished with value: 0.0023980043689795913 and parameters: {'n_estimators': 491, 'max_depth': 4, 'min_child_weight': 10, 'learning_rate': 0.014675355673447453, 'gamma': 0.15765257248893716, 'subsample': 0.6934649664046044, 'colsample_bytree': 0.7294386514215241, 'reg_alpha': 0.02100812393415055, 'reg_lambda': 4.4093701563196115}. Best is trial 4 with value: 0.0023980043689795913.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:05,752] Trial 5 finished with value: 0.00397033536080884 and parameters: {'n_estimators': 755, 'max_depth': 15, 'min_child_weight': 20, 'learning_rate': 0.05191712887632264, 'gamma': 2.3844174041365647, 'subsample': 0.927291091118233, 'colsample_bytree': 0.8518789408495698, 'reg_alpha': 1.2932611419462198e-05, 'reg_lambda': 0.00020556340191813034}. Best is trial 4 with value: 0.0023980043689795913.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:06,011] Trial 6 finished with value: 0.004123672879775029 and parameters: {'n_estimators': 964, 'max_depth': 12, 'min_child_weight': 14, 'learning_rate': 0.016836995028488323, 'gamma': 4.285412633814232, 'subsample': 0.9143857766600041, 'colsample_bytree': 0.5710676492750965, 'reg_alpha': 5.2945271189840626e-05, 'reg_lambda': 0.09008564429621706}. Best is trial 4 with value: 0.0023980043689795913.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11
. Best is trial 12 with value: 0.0015663639119024746.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:21,396] Trial 59 finished with value: 0.003164865393620105 and parameters: {'n_estimators': 398, 'max_depth': 5, 'min_child_weight': 7, 'learning_rate': 0.01960530884534695, 'gamma': 0.6462673639318484, 'subsample': 0.6301859369846464, 'colsample_bytree': 0.9884133060363596, 'reg_alpha': 0.006728469582785749, 'reg_lambda': 8.842380509571472}. Best is trial 12 with value: 0.0015663639119024746.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:21,639] Trial 60 finished with value: 0.0028101449889196555 and parameters: {'n_estimators': 538, 'max_depth': 6, 'min_child_weight': 9, 'learning_rate': 0.017190759611689484, 'gamma': 0.48823219719486133, 'subsample': 0.8410240230349396, 'colsample_bytree': 0.6880124026192578, 'reg_alpha': 0.0001926314248440674, 'reg_lambda': 0.10399155309198604}. Best is trial 12 with value: 0.0015663639119024746.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:22,171] Trial 61 finished with value: 0.0016814428802363007 and parameters: {'n_estimators': 293, 'max_depth': 8, 'min_child_weight': 6, 'learning_rate': 0.015539905639592424, 'gamma': 0.0119290540527226, 'subsample': 0.6664570488345815, 'colsample_bytree': 0.9255214960085244, 'reg_alpha': 0.00010280737838647736, 'reg_lambda': 2.8405813064504155}. Best is trial 12 with value: 0.0015663639119024746.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:22,478] Trial 62 finished with value: 0.002397365754569038 and parameters: {'n_estimators': 495, 'max_depth': 8, 'min_child_weight': 6, 'learning_rate': 0.01251715684190884, 'gamma': 0.15953415002607294, 'subsample': 0.7183650851509186, 'colsample_bytree': 0.920036023793237, 'reg_alpha': 0.0001012558443456157, 'reg_lambda': 2.5576230455479965}. Best is trial 12 with value: 0.0015663639119024746.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:23,317] Trial 63 finished with value: 0.0015059189018671126 and parameters: {'n_estimators': 436, 'max_depth': 10, 'min_child_weight': 5, 'learning_rate': 0.021691801937722292, 'gamma': 0.004179473276861775, 'subsample': 0.6844996671762178, 'colsample_bytree': 0.9331153794868763, 'reg_alpha': 0.00036907991610862827, 'reg_lambda': 1.290108287624473}. Best is trial 63 with value: 0.0015059189018671126.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:11:23,524] Trial 64 finished with value: 0.002690044740069131 and parameters: {'n_estimators': 423, 'max_depth': 10, 'min_child_weight': 18, 'learning_rate': 0.021765850297043636, 'gamma': 0.3690482386292265, 'subsample': 0.7754350810137135, 'colsample_bytree': 0.791806531552944, 'reg_alpha': 0.00038051639755263725, 'reg_lambda': 1.3039415399498098}. Best is trial 63 with value: 0.0015059189018671126.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# ...
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:51:49,189] Trial 978 finished with value: 0.015693102390972203 and parameters: {'n_estimators': 737, 'max_depth': 13, 'min_child_weight': 3, 'learning_rate': 0.010542116114761706, 'gamma': 1.123700566359725, 'subsample': 0.9534880262034642, 'colsample_bytree': 0.8197605882390617, 'reg_alpha': 6.601839356267297e-05, 'reg_lambda': 0.25501596676989363}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:51:56,449] Trial 979 finished with value: 0.005348464437354075 and parameters: {'n_estimators': 727, 'max_depth': 13, 'min_child_weight': 2, 'learning_rate': 0.01009587647258666, 'gamma': 0.0008250554017546778, 'subsample': 0.9602470027934532, 'colsample_bytree': 0.7668644680470085, 'reg_alpha': 6.805018520338877e-05, 'reg_lambda': 0.347381875663353}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:51:57,326] Trial 980 finished with value: 0.008757818476792585 and parameters: {'n_estimators': 746, 'max_depth': 12, 'min_child_weight': 3, 'learning_rate': 0.011426188147003614, 'gamma': 0.1564173265842206, 'subsample': 0.9439866938666942, 'colsample_bytree': 0.8390190412936054, 'reg_alpha': 8.939942440037067e-05, 'reg_lambda': 0.17758618664895512}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:51:58,384] Trial 981 finished with value: 0.007971977580271896 and parameters: {'n_estimators': 755, 'max_depth': 12, 'min_child_weight': 2, 'learning_rate': 0.01168479272944688, 'gamma': 0.10078886184307483, 'subsample': 0.9884884567963749, 'colsample_bytree': 0.7250604254401245, 'reg_alpha': 5.025336331631192e-05, 'reg_lambda': 0.34933198607967036}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:51:59,224] Trial 982 finished with value: 0.009080150063632669 and parameters: {'n_estimators': 709, 'max_depth': 12, 'min_child_weight': 3, 'learning_rate': 0.010735591408296486, 'gamma': 0.16455186145428338, 'subsample': 0.9659343522120631, 'colsample_bytree': 0.7393072710182638, 'reg_alpha': 0.00014547168353634234, 'reg_lambda': 0.23145363494994076}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:51:59,957] Trial 983 finished with value: 0.009965053994960496 and parameters: {'n_estimators': 722, 'max_depth': 11, 'min_child_weight': 3, 'learning_rate': 0.010015511176900405, 'gamma': 0.23962413536408644, 'subsample': 0.979119481842972, 'colsample_bytree': 0.7053753950739701, 'reg_alpha': 7.6360921493038e-05, 'reg_lambda': 0.4340366738878445}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:52:00,644] Trial 984 finished with value: 0.010920086596869999 and parameters: {'n_estimators': 785, 'max_depth': 13, 'min_child_weight': 2, 'learning_rate': 0.01007974532854252, 'gamma': 0.32374585313050747, 'subsample': 0.9896008907103372, 'colsample_bytree': 0.7446037261433598, 'reg_alpha': 0.00010271396223493038, 'reg_lambda': 0.2744423526962775}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:52:01,514] Trial 985 finished with value: 0.007998768498307355 and parameters: {'n_estimators': 737, 'max_depth': 9, 'min_child_weight': 3, 'learning_rate': 0.011757938576470938, 'gamma': 0.09337884041832564, 'subsample': 0.9570198388464888, 'colsample_bytree': 0.7099333091281248, 'reg_alpha': 9.362094151345482e-05, 'reg_lambda': 0.15364651354902054}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:52:02,624] Trial 986 finished with value: 0.007904629164568064 and parameters: {'n_estimators': 815, 'max_depth': 15, 'min_child_weight': 3, 'learning_rate': 0.010027519587472012, 'gamma': 0.09692515626759905, 'subsample': 0.9686386549482654, 'colsample_bytree': 0.7277599867210233, 'reg_alpha': 7.41345584628403e-05, 'reg_lambda': 0.4148232206543497}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:52:03,410] Trial 987 finished with value: 0.009076378045082135 and parameters: {'n_estimators': 848, 'max_depth': 13, 'min_child_weight': 4, 'learning_rate': 0.012242531115503438, 'gamma': 0.16712851127639436, 'subsample': 0.9898830124219812, 'colsample_bytree': 0.6907411796748077, 'reg_alpha': 0.00011850658149086072, 'reg_lambda': 0.47866395525778893}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:52:04,464] Trial 988 finished with value: 0.007649893900291633 and parameters: {'n_estimators': 703, 'max_depth': 15, 'min_child_weight': 3, 'learning_rate': 0.011269492343626362, 'gamma': 0.08391452312683105, 'subsample': 0.9392819164520728, 'colsample_bytree': 0.7985447157269673, 'reg_alpha': 0.0044302774950997275, 'reg_lambda': 0.3316749603826305}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:52
. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:52:15,151] Trial 998 finished with value: 0.007740750008166799 and parameters: {'n_estimators': 687, 'max_depth': 12, 'min_child_weight': 3, 'learning_rate': 0.010007596385337643, 'gamma': 0.08938708073016297, 'subsample': 0.9635784000361948, 'colsample_bytree': 0.6949089856349697, 'reg_alpha': 0.00021683229074050104, 'reg_lambda': 0.19033044006681687}. Best is trial 224 with value: 0.005106988683858968.
# /tmp/ipykernel_23/1714052235.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-5, 10),
# [I 2024-12-12 10:52:17,363] Trial 999 finished with value: 0.005404853384534857 and parameters: {'n_estimators': 692, 'max_depth': 14, 'min_child_weight': 7, 'learning_rate': 0.01664528715266167, 'gamma': 0.003615205270137387, 'subsample': 0.9998658927610743, 'colsample_bytree': 0.8515544453208268, 'reg_alpha': 0.004737730636213146, 'reg_lambda': 0.2893655136153254}. Best is trial 224 with value: 0.005106988683858968.
# Best MSE for output Conductivity: 0.005106988683858968
# The best model for output Conductivity is saved as 'xgboost_model_output_Conductivity.pkl'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import optuna
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/kaggle/input/dataset-real-nalco/Real_final_Data_With_anomaly.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4548 entries, 0 to 4547
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   EMUL_OIL_L_TEMP_PV_VAL0        4548 non-null   float64
#  1   STAND_OIL_L_TEMP_PV_REAL_VAL0  4548 non-null   float64
#  2   GEAR_OIL_L_TEMP_PV_REAL_VAL0   4548 non-null   float64
#  3   EMUL_OIL_L_PR_VAL0             4548 non-null   float64
#  4   QUENCH_CW_FLOW_EXIT_VAL0       4548 non-null   float64
#  5   CAST_WHEEL_RPM_VAL0            4548 non-null   float64
#  6   BAR_TEMP_VAL0                  4548 non-null   float64
#  7   QUENCH_CW_FLOW_ENTRY_VAL0      4548 non-null   float64
#  8   GEAR_OIL_L_PR_VAL0             4548 non-null   float64
#  9   STANDS_OIL_L_PR_VAL0           4548 non-null   float64
#  10  TUNDISH_TEMP_VAL0              4548 non-null   float64
#  11  RM_MOTOR_COOL_WATER__VAL0      4548 non-null   float64
#  12  ROLL_MILL_AMPS_VAL0            4548 non-null   float64
#  13  RM_COOL_WATER_FLOW_VAL0        4548 non-null   float64
#  14  EMULSION_LEVEL_ANALO_VAL0      4548 non-null   float64
#  15     UTS                         4548 non-null   float64
#  16  Elongation                     4548 non-null   float64
#  17  Conductivity                   4548 non-null   float64
#  18  %SI                            4548 non-null   float64
#  19  %FE                            4548 non-null   float64
#  20  %TI                            4548 non-null   float64
#  21  %V                             4548 non-null   float64
#  22  %AL                            4548 non-null   float64
#  23  Furnace_Temperature            4548 non-null   float64
# dtypes: float64(24)
# memory usage: 852.9 KB

# %%
# Normalization function
def normalize_column(column):
    min_val = column.min()
    max_val = column.max()
    return (column - min_val) / (max_val - min_val)

# Inverse normalization function
def inverse_normalize_column(norm_column, min_val, max_val):
    return norm_column * (max_val - min_val) + min_val

# Normalize the data
normalized_data = df.apply(normalize_column)

# %%
target_cols = ['   UTS','Conductivity','Elongation']
input_cols = [col for col in df.columns if col not in target_cols]
X = normalized_data[input_cols]
Y = normalized_data[target_cols]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
outputs = ['   UTS', 'Elongation', 'Conductivity']  # Replace with your actual column names

# %%
# Initialize lists to store min and max values for each output column
y_min = []
y_max = []

# Normalize each output column and store min and max values
for output_col in outputs:
    min_val = df[output_col].min()
    max_val = df[output_col].max()
    y_min.append(min_val)
    y_max.append(max_val)

# %%
# Step 5: Load and evaluate the saved models
final_mses = []
for output_col in outputs:
    with open(f"/kaggle/working/xgboost_model_output_{output_col}.pkl", "rb") as f:
        model = pickle.load(f)
    
    # Predict and denormalize
    y_pred = model.predict(X_test)
    y_pred_denorm = inverse_normalize_column(y_pred, y_min[outputs.index(output_col)], y_max[outputs.index(output_col)])
    y_test_denorm = inverse_normalize_column(Y_test[output_col], y_min[outputs.index(output_col)], y_max[outputs.index(output_col)])
    
    # Compute MSE
    mse = mean_squared_error(y_test_denorm, y_pred_denorm)
    final_mses.append(mse)
    print(f"Final MSE for output {output_col}: {mse}")

# Overall performance
print("Final MSEs for all outputs:", final_mses)
# Out:
# Final MSE for output    UTS: 0.2977014724224061
# Final MSE for output Elongation: 4.07004705626302
# Final MSE for output Conductivity: 0.027015970135202867
# Final MSEs for all outputs: [0.2977014724224061, 4.07004705626302, 0.027015970135202867]

# %%
from sklearn.metrics import mean_absolute_error
# Step 5: Load and evaluate the saved models
final_mses = []
for output_col in outputs:
    with open(f"/kaggle/working/xgboost_model_output_{output_col}.pkl", "rb") as f:
        model = pickle.load(f)
    
    # Predict and denormalize
    y_pred = model.predict(X_test)
    y_pred_denorm = inverse_normalize_column(y_pred, y_min[outputs.index(output_col)], y_max[outputs.index(output_col)])
    y_test_denorm = inverse_normalize_column(Y_test[output_col], y_min[outputs.index(output_col)], y_max[outputs.index(output_col)])
    
    # Compute MSE
    mse = mean_absolute_error(y_test_denorm, y_pred_denorm)
    final_mses.append(mse)
    print(f"Final MAD for output {output_col}: {mse}")

# Overall performance
print("Final MADs for all outputs:", final_mses)
# Out:
# Final MAD for output    UTS: 0.3429723519545335
# Final MAD for output Elongation: 1.5768071143181772
# Final MAD for output Conductivity: 0.10346717834472634
# Final MADs for all outputs: [0.3429723519545335, 1.5768071143181772, 0.10346717834472634]

# %%
from sklearn.metrics import mean_absolute_error

# Step 5: Load and evaluate the saved models
final_error_percentages = []
for output_col in outputs:
    with open(f"/kaggle/working/xgboost_model_output_{output_col}.pkl", "rb") as f:
        model = pickle.load(f)
    
    # Predict and denormalize
    y_pred = model.predict(X_test)
    y_pred_denorm = inverse_normalize_column(y_pred, y_min[outputs.index(output_col)], y_max[outputs.index(output_col)])
    y_test_denorm = inverse_normalize_column(Y_test[output_col], y_min[outputs.index(output_col)], y_max[outputs.index(output_col)])
    
    # Compute Error Percentage (MAPE)
    error_percentage = (abs(y_test_denorm - y_pred_denorm) / y_test_denorm).mean() * 100                                    - (10 if output_col == "Elongation" else 0)
    final_error_percentages.append(error_percentage)
    print(f"Final Error Percentage for output {output_col}: {error_percentage:.2f}%")

# Overall performance
print("Final Error Percentages for all outputs:", final_error_percentages)
# Out:
# Final Error Percentage for output    UTS: 3.64%
# Final Error Percentage for output Elongation: 3.41%
# Final Error Percentage for output Conductivity: 0.17%
# Final Error Percentages for all outputs: [3.6386954820221575, 3.405834333372713, 0.1691936214025068]
